# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('benefit_area.csv')
df
# Out:
#      Unnamed: 0                                               Name  \
# 0             0  Dr Willmar Schwabe India Berberis Aquifolium M...
# 1             1         SBL Arnica Montana Herbal Shampoo with TJC
# 2             2                             SBL Jaborandi Hair Oil
# 3             3                SBL Cineraria Maritima 10% Eye Drop
# 4             4                       Bjain Guatteria Gaumeri Drop
# ..          ...                                                ...
# 720         720                   ADEL Hydrangea Mother Tincture Q
# 721         721                  ADEL Symphytum. Mother Tincture Q
# 722         722     SBL Arsenic Sulphuratum Flavum Dilution 200 CH
# 723         723                 Dr Batra's Hair Fall Control Serum
# 724         724              ADEL Ferrum Mur Trituration Tablet 3X
#
#                          benefit_area
# 0    eye, legs, skin, face, eyes, ear
# 1                                hair
# 2                                hair
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Name              0
# benefit_area    280
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Name            0
# benefit_area    0
# dtype: int64

# %%
df.shape
# Out:
# (445, 3)

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                                                   Name  \
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...
# 1           SBL Arnica Montana Herbal Shampoo with TJC
# 2                               SBL Jaborandi Hair Oil
# 4                         Bjain Guatteria Gaumeri Drop
# 5             SBL Sarracenia Purpurea Dilution 1000 CH
# ..                                                 ...
# 715                         SBL Arsenicum Album 0/1 LM
# 716                             Lord's Pediclean Cream
# 719  Dr Willmar Schwabe India Psorinum Dilution 100...
# 723                 Dr Batra's Hair Fall Control Serum
# 724              ADEL Ferrum Mur Trituration Tablet 3X
#
#                          benefit_area
# 0    eye, legs, skin, face, eyes, ear
# 1                                hair
# 2                                hair
# 4                               blood
# 5                     skin, eye, eyes
# ..                                ...
# ...

# %%
df2=pd.read_csv('Table1.csv')
df2
# Out:
#                                                   Name  Size Unit  MRP  price  \
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...    30   ml  210    179
# 1           SBL Arnica Montana Herbal Shampoo with TJC   200   ml  160    129
# 2                               SBL Jaborandi Hair Oil   200   ml  255    208
# 3                  SBL Cineraria Maritima 10% Eye Drop    10   ml  130    109
# 4                         Bjain Guatteria Gaumeri Drop    30   ml  345    283
# ..                                                 ...   ...  ...  ...    ...
# 795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH    11   ml  135    118
# 796                     ADEL Bio-Combination 25 Tablet    20   gm  180    162
# 797                     ADEL Aconite Nap.  Dilution CM    10   ml  290    261
# 798      SBL Natrum Phosphoricum Biochemic Tablet 200X    25   gm  100     81
# 799      Wheezal WL06 Cervical Spondylitis (Mild) Drop    30   ml  170    148
#
# ...

# %%
df2.isnull().sum()
# Out:
# Name     0
# Size     0
# Unit     0
# MRP      0
# price    0
# url      0
# dtype: int64

# %%
df3=pd.read_csv('Table2a.csv')
df3
# Out:
#      Unnamed: 0                                               Name  Rating  \
# 0             0  Dr Willmar Schwabe India Berberis Aquifolium M...     4.3
# 1             1         SBL Arnica Montana Herbal Shampoo with TJC     4.4
# 2             2                             SBL Jaborandi Hair Oil     4.4
# 3             3                SBL Cineraria Maritima 10% Eye Drop     4.5
# 4             4                       Bjain Guatteria Gaumeri Drop     4.6
# ..          ...                                                ...     ...
# 795         795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH     NaN
# 796         796                     ADEL Bio-Combination 25 Tablet     NaN
# 797         797                     ADEL Aconite Nap.  Dilution CM     5.0
# 798         798      SBL Natrum Phosphoricum Biochemic Tablet 200X     4.6
# 799         799      Wheezal WL06 Cervical Spondylitis (Mild) Drop     NaN
#
#       Num_rating
# 0    369 ratings
# 1    326 ratings
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0      0
# Name            0
# Rating        126
# Num_rating    126
# dtype: int64

# %%
df3.fillna(0,inplace=True)

# %%
df3
# Out:
#      Unnamed: 0                                               Name  Rating  \
# 0             0  Dr Willmar Schwabe India Berberis Aquifolium M...     4.3
# 1             1         SBL Arnica Montana Herbal Shampoo with TJC     4.4
# 2             2                             SBL Jaborandi Hair Oil     4.4
# 3             3                SBL Cineraria Maritima 10% Eye Drop     4.5
# 4             4                       Bjain Guatteria Gaumeri Drop     4.6
# ..          ...                                                ...     ...
# 795         795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH     0.0
# 796         796                     ADEL Bio-Combination 25 Tablet     0.0
# 797         797                     ADEL Aconite Nap.  Dilution CM     5.0
# 798         798      SBL Natrum Phosphoricum Biochemic Tablet 200X     4.6
# 799         799      Wheezal WL06 Cervical Spondylitis (Mild) Drop     0.0
#
#       Num_rating
# 0    369 ratings
# 1    326 ratings
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Rating        0
# Num_rating    0
# dtype: int64

# %%
df3=df3.drop('Unnamed: 0',axis=1)

# %%
df3
# Out:
#                                                   Name  Rating   Num_rating
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...     4.3  369 ratings
# 1           SBL Arnica Montana Herbal Shampoo with TJC     4.4  326 ratings
# 2                               SBL Jaborandi Hair Oil     4.4  116 ratings
# 3                  SBL Cineraria Maritima 10% Eye Drop     4.5   94 ratings
# 4                         Bjain Guatteria Gaumeri Drop     4.6  119 ratings
# ..                                                 ...     ...          ...
# 795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH     0.0            0
# 796                     ADEL Bio-Combination 25 Tablet     0.0            0
# 797                     ADEL Aconite Nap.  Dilution CM     5.0    5 ratings
# 798      SBL Natrum Phosphoricum Biochemic Tablet 200X     4.6  106 ratings
# 799      Wheezal WL06 Cervical Spondylitis (Mild) Drop     0.0            0
#
# [800 rows x 3 columns]

# %%
df3['Num_rating']=df3.Num_rating.str.extract('(\d+)')

# %%
df3
# Out:
#                                                   Name  Rating Num_rating
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...     4.3        369
# 1           SBL Arnica Montana Herbal Shampoo with TJC     4.4        326
# 2                               SBL Jaborandi Hair Oil     4.4        116
# 3                  SBL Cineraria Maritima 10% Eye Drop     4.5         94
# 4                         Bjain Guatteria Gaumeri Drop     4.6        119
# ..                                                 ...     ...        ...
# 795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH     0.0        NaN
# 796                     ADEL Bio-Combination 25 Tablet     0.0        NaN
# 797                     ADEL Aconite Nap.  Dilution CM     5.0          5
# 798      SBL Natrum Phosphoricum Biochemic Tablet 200X     4.6        106
# 799      Wheezal WL06 Cervical Spondylitis (Mild) Drop     0.0        NaN
#
# [800 rows x 3 columns]

# %%
df3.fillna(0,inplace=True)

# %%
df3
# Out:
#                                                   Name  Rating Num_rating
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...     4.3        369
# 1           SBL Arnica Montana Herbal Shampoo with TJC     4.4        326
# 2                               SBL Jaborandi Hair Oil     4.4        116
# 3                  SBL Cineraria Maritima 10% Eye Drop     4.5         94
# 4                         Bjain Guatteria Gaumeri Drop     4.6        119
# ..                                                 ...     ...        ...
# 795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH     0.0          0
# 796                     ADEL Bio-Combination 25 Tablet     0.0          0
# 797                     ADEL Aconite Nap.  Dilution CM     5.0          5
# 798      SBL Natrum Phosphoricum Biochemic Tablet 200X     4.6        106
# 799      Wheezal WL06 Cervical Spondylitis (Mild) Drop     0.0          0
#
# [800 rows x 3 columns]

# %%
df3.to_csv('table2_rating.csv')

# %%
df
# Out:
#                                                   Name  \
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...
# 1           SBL Arnica Montana Herbal Shampoo with TJC
# 2                               SBL Jaborandi Hair Oil
# 4                         Bjain Guatteria Gaumeri Drop
# 5             SBL Sarracenia Purpurea Dilution 1000 CH
# ..                                                 ...
# 715                         SBL Arsenicum Album 0/1 LM
# 716                             Lord's Pediclean Cream
# 719  Dr Willmar Schwabe India Psorinum Dilution 100...
# 723                 Dr Batra's Hair Fall Control Serum
# 724              ADEL Ferrum Mur Trituration Tablet 3X
#
#                          benefit_area
# 0    eye, legs, skin, face, eyes, ear
# 1                                hair
# 2                                hair
# 4                               blood
# 5                     skin, eye, eyes
# ..                                ...
# ...

# %%
df.to_csv('table2_benefit.csv')

# %%
df2
# Out:
#                                                   Name  Size Unit  MRP  price  \
# 0    Dr Willmar Schwabe India Berberis Aquifolium M...    30   ml  210    179
# 1           SBL Arnica Montana Herbal Shampoo with TJC   200   ml  160    129
# 2                               SBL Jaborandi Hair Oil   200   ml  255    208
# 3                  SBL Cineraria Maritima 10% Eye Drop    10   ml  130    109
# 4                         Bjain Guatteria Gaumeri Drop    30   ml  345    283
# ..                                                 ...   ...  ...  ...    ...
# 795   Dr. Reckeweg Petroselinum Sativum Dilution 30 CH    11   ml  135    118
# 796                     ADEL Bio-Combination 25 Tablet    20   gm  180    162
# 797                     ADEL Aconite Nap.  Dilution CM    10   ml  290    261
# 798      SBL Natrum Phosphoricum Biochemic Tablet 200X    25   gm  100     81
# 799      Wheezal WL06 Cervical Spondylitis (Mild) Drop    30   ml  170    148
#
# ...
